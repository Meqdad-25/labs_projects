# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # ARIMA & SARIMA Lab
#
# ---

# %% [markdown]
# ## Learning Objectives
#
# ### Core
# - Test a time series for stationarity and determine the order of differencing (d)
# - Use ACF/PACF plots to reason about AR and MA terms
# - Fit an ARIMA model, forecast, and evaluate it
# - Detect seasonality in a series and fit a SARIMA model
# - Compare ARIMA vs. SARIMA performance on the same data and explain why one wins
#
# ### Target
# - Use `auto_arima` to search for (p,d,q) and seasonal (P,D,Q,m) orders
# - Produce forecasts with confidence intervals

# %% [markdown]
# ## Scenario
#
# You are a data scientist and were given the monthly airline passenger counts. Your manager wants a short-term forecast, and wants to know whether a simple ARIMA model is good enough or whether the extra complexity of SARIMA is worth it.
#
# You will build both models on the same data and test which model is better.

# %% [markdown]
# ## 0. Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

np.set_printoptions(precision=4)
sns.set(font_scale=1.5)
plt.style.use('fivethirtyeight')

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
from statsmodels.tsa.stattools import acf, pacf, adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tools.eval_measures import rmse
from pmdarima import auto_arima

# %% [markdown]
# <div class="alert alert-info"><strong>What is the below function?:</strong> Function for running the augmented Dickey-Fuller test (adfuller).</div>

# %%
def adf_test(series, title=''):
    """
    Pass in a time series and an optional title, returns an ADF report
    """
    print(f'Augmented Dickey-Fuller Test: {title}')
    result = adfuller(series.dropna(),autolag='AIC') # .dropna() handles differenced data
    
    labels = ['ADF test statistic','p-value','# lags used','# observations']
    out = pd.Series(result[0:4],index=labels)

    for key,val in result[4].items():
        out[f'critical value ({key})']=val
        
    print(out.to_string())          # .to_string() removes the line "dtype: float64"
    
    if result[1] <= 0.05:
        print("Strong evidence against the null hypothesis")
        print("Reject the null hypothesis")
        print("Data has no unit root and is stationary")
    else:
        print("Weak evidence against the null hypothesis")
        print("Fail to reject the null hypothesis")
        print("Data has a unit root and is non-stationary")

# %% [markdown]
# <div class="alert alert-info"><strong>What is the below function?:</strong> plot ACF and PACF beside each other.</div>

# %%
def autocorr_plots(y, lags=None):
    fig, ax = plt.subplots(ncols=2, figsize=(12, 4), sharey=True)
    plot_acf(y, lags=lags, ax=ax[0])
    plot_pacf(y, lags=lags, ax=ax[1])
    return fig, ax

# %% [markdown]
# ## 1. Load and inspect the data
#
# This is historical monthly airline passenger counts (in thousands).

# %%
# 1a. Load the dataset, parsing the 'month' column as dates
df = pd.read_csv('./airline_passengers.csv', parse_dates=['month'])
df
# Out:
#          month  thousands_of_passengers
# 0   1949-01-01                      112
# 1   1949-02-01                      118
# 2   1949-03-01                      132
# 3   1949-04-01                      129
# 4   1949-05-01                      121
# ..         ...                      ...
# 139 1960-08-01                      606
# 140 1960-09-01                      508
# 141 1960-10-01                      461
# 142 1960-11-01                      390
# 143 1960-12-01                      432
#
# [144 rows x 2 columns]

# %%
# 1b. Set 'month' as an Index and set the frequency to Monthly-Start (use resamling).
df = df.set_index('month')
df = df.resample('MS').mean()


df.head()
# Out:
#             thousands_of_passengers
# month
# 1949-01-01                    112.0
# 1949-02-01                    118.0
# 1949-03-01                    132.0
# 1949-04-01                    129.0
# 1949-05-01                    121.0

# %%
# 1c. Plot the full series and look at shape.
df['thousands_of_passengers'].plot(figsize=(12, 5))
plt.title('Monthly airline passengers')
plt.ylabel('Passengers (thousands)')
plt.xlabel('')
plt.show()

# %% [markdown]
# ---
# # Part A - ARIMA
#
# We'll start simple: treat this as a general time series and build a non-seasonal ARIMA model. Follow the same workflow:
#
# > **Stationarity -> Differencing -> ACF/PACF -> Fit -> Evaluate**.

# %% [markdown]
# ### A1. Check stationarity

# %%
# Run adf_test on the passenger series. Is it stationary?
adf_test(df['thousands_of_passengers'], title='Raw series')
# Out:
# Augmented Dickey-Fuller Test: Raw series
# ADF test statistic        0.815369
# p-value                   0.991880
# # lags used              13.000000
# # observations          130.000000
# critical value (1%)      -3.481682
# critical value (5%)      -2.884042
# critical value (10%)     -2.578770
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non-stationary

# %% [markdown]
# ### A2. Difference until stationary
#
# If the series isn't stationary, difference it (`.diff()`) and re-run the ADF test. Keep track of how many differences it took - that's your `d`.

# %%
# Difference once and re-test
adf_test(df['thousands_of_passengers'].diff(), title='First difference')
# Out:
# Augmented Dickey-Fuller Test: First difference
# ADF test statistic       -2.829267
# p-value                   0.054213
# # lags used              12.000000
# # observations          130.000000
# critical value (1%)      -3.481682
# critical value (5%)      -2.884042
# critical value (10%)     -2.578770
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non-stationary

# %%
# If needed, difference a second time and re-test
adf_test(df['thousands_of_passengers'].diff().diff(), title='Second difference')
# Out:
# Augmented Dickey-Fuller Test: Second difference
# ADF test statistic     -1.638423e+01
# p-value                 2.732892e-29
# # lags used             1.100000e+01
# # observations          1.300000e+02
# critical value (1%)    -3.481682e+00
# critical value (5%)    -2.884042e+00
# critical value (10%)   -2.578770e+00
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary

# %% [markdown]
# **Write down your `d` value here:**
#
# `d = 2`

# %% [markdown]
# ### A3. ACF / PACF on the differenced series
#
# Use `autocorr_plots()` on your *stationary* (differenced) series.

# %%
# Plot ACF and PACF on the differenced series, lags=24
autocorr_plots(df['thousands_of_passengers'].diff().diff().dropna(), lags=24);

# %% [markdown]
# **Based on the plots above, what would you guess for `p` and `q`?**
#
# - p (AR terms): 1 or 2
# - q (MA terms): 1 or 2

# %% [markdown]
# ### A4. Confirm with auto_arima
#
# Now check your manual guess against `auto_arima`. Keep `seasonal=False` as we are not modeling seasonality in Part A.

# %%
# Run auto_arima with seasonal=False and print the summary
auto_model = auto_arima(df['thousands_of_passengers'],
                        seasonal=False,       
                        trace=True,           
                        error_action='ignore',
                        suppress_warnings=True)

auto_model.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.58 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1415.278, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1403.473, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1398.827, Time=0.10 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=1413.909, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=1396.121, Time=0.17 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.32 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.20 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=1398.386, Time=0.15 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=1397.975, Time=0.08 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=1394.683, Time=0.08 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=1397.258, Time=0.07 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=1401.852, Time=0.05 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=1378.338, Time=0.08 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=1396.588, Time=0.06 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=1379.614, Time=0.23 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=inf, Time=0.38 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=1385.498, Time=0.11 sec
#  ARIMA(3,1,0)(0,0,0)[0]             : AIC=1395.021, Time=0.10 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=1377.086, Time=0.23 sec
#  ARIMA(4,1,2)(0,0,0)[0]             : AIC=1373.560, Time=0.31 sec
#  ARIMA(4,1,1)(0,0,0)[0]             : AIC=1384.053, Time=0.26 sec
#  ARIMA(5,1,2)(0,0,0)[0]             : AIC=1375.353, Time=0.38 sec
#  ARIMA(4,1,3)(0,0,0)[0]             : AIC=1365.825, Time=0.59 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=inf, Time=0.63 sec
#  ARIMA(5,1,3)(0,0,0)[0]             : AIC=inf, Time=0.74 sec
#  ARIMA(4,1,4)(0,0,0)[0]             : AIC=inf, Time=0.79 sec
#  ARIMA(3,1,4)(0,0,0)[0]             : AIC=inf, Time=0.73 sec
#  ARIMA(5,1,4)(0,0,0)[0]             : AIC=inf, Time=0.76 sec
#  ARIMA(4,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.72 sec
#
# Best model:  ARIMA(4,1,3)(0,0,0)[0]
# Total fit time: 9.055 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  144
# Model:               SARIMAX(4, 1, 3)   Log Likelihood                -674.913
# Date:                Fri, 14 Aug 2026   AIC                           1365.825
# Time:                        23:28:02   BIC                           1389.528
# Sample:                    01-01-1949   HQIC                          1375.457
#                          - 12-01-1960
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.5582      0.117     -4.782      0.000      -0.787      -0.329
# ar.L2          0.4935      0.113      4.375      0.000       0.272       0.715
# ar.L3          0.1238      0.128      0.970      0.332      -0.126       0.374
# ar.L4         -0.5213      0.085     -6.136      0.000      -0.688      -0.355
# ma.L1          0.9069      0.094      9.657      0.000       0.723       1.091
# ma.L2         -0.5590      0.145     -3.866      0.000      -0.842      -0.276
# ma.L3         -0.7385      0.109     -6.778      0.000      -0.952      -0.525
# sigma2       724.1727     85.616      8.458      0.000     556.369     891.976
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.37   Jarque-Bera (JB):                14.59
# Prob(Q):                              0.54   Prob(JB):                         0.00
# Heteroskedasticity (H):               5.66   Skew:                             0.74
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.52
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ### A5. Train, Test, and Split
#
# Hold out the last 12 months as your test set.

# %%
# Split into df_train (all but last 12 rows) and df_test (last 12 rows)
df_train = df.iloc[:-12]
df_test = df.iloc[-12:]

# %% [markdown]
# ### A6. Fit the ARIMA model
#
# Use the (p,d,q) order from A4.

# %%
# Fit ARIMA(p,d,q) on the training set
model_arima = ARIMA(df_train['thousands_of_passengers'], order=(4, 1, 3))
result_arima = model_arima.fit()

result_arima.summary()
# Out:
# C:\Users\meqda\GA_DSB\ga_dsb_env\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\meqda\GA_DSB\ga_dsb_env\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                   SARIMAX Results
# ===================================================================================
# Dep. Variable:     thousands_of_passengers   No. Observations:                  132
# Model:                      ARIMA(4, 1, 3)   Log Likelihood                -607.206
# Date:                     Fri, 14 Aug 2026   AIC                           1230.412
# Time:                             23:31:09   BIC                           1253.414
# Sample:                         01-01-1949   HQIC                          1239.759
#                               - 12-01-1959
# Covariance Type:                       opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.5693      0.115     -4.968      0.000      -0.794      -0.345
# ar.L2          0.4828      0.123      3.935      0.000       0.242       0.723
# ar.L3          0.1164      0.128      0.911      0.362      -0.134       0.367
# ar.L4         -0.5331      0.084     -6.378      0.000      -0.697      -0.369
# ma.L1          0.9304      0.103      8.994      0.000       0.728       1.133
# ma.L2         -0.5541      0.151     -3.670      0.000      -0.850      -0.258
# ma.L3         -0.7290      0.102     -7.155      0.000      -0.929      -0.529
# sigma2       607.4737     76.263      7.965      0.000     458.000     756.947
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.20   Jarque-Bera (JB):                11.03
# Prob(Q):                              0.65   Prob(JB):                         0.00
# Heteroskedasticity (H):               4.40   Skew:                             0.69
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.38
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ### A7. Predict on the test set

# %%
# Predict over the test period
start = len(df_train)
end = len(df_train) + len(df_test) - 1

pred_arima = result_arima.predict(start=start, end=end).rename('ARIMA(4,1,3) Predictions')
pred_arima
# Out:
# 1960-01-01    441.014245
# 1960-02-01    446.034164
# 1960-03-01    469.988829
# 1960-04-01    440.043181
# 1960-05-01    450.040026
# 1960-06-01    430.002104
# 1960-07-01    429.978876
# 1960-08-01    437.445821
# 1960-09-01    425.521802
# 1960-10-01    446.595420
# 1960-11-01    429.723135
# 1960-12-01    444.134242
# Freq: MS, Name: ARIMA(4,1,3) Predictions, dtype: float64

# %%
# Plot the test data vs predictions
title = 'ARIMA(4,1,3): predictions vs actual'
ax = pred_arima.plot(legend=True, figsize=(12, 5), title=title)
df_test['thousands_of_passengers'].plot(legend=True, ax=ax)
ax.legend(['ARIMA predicted', 'Actual test data'])
plt.show()

# %% [markdown]
# ### A8. Evaluate
#
# Compute RMSE for the ARIMA model. Also print the mean of the series so you have something to compare the error against.

# %%
# Compute RMSE
error_arima = rmse(df_test['thousands_of_passengers'], pred_arima)

print(f'ARIMA(4,1,3) RMSE: {error_arima:.4f}')
print(f'Mean: {df["thousands_of_passengers"].mean():.4f}')
# Out:
# ARIMA(4,1,3) RMSE: 87.6400
# Mean: 280.2986

# %% [markdown]
# ---
# # Part B - SARIMA
#
# Now let's actually look at *why* the ARIMA forecast missed. This is where we introduce seasonality.

# %% [markdown]
# ### B1. Seasonal decomposition
#
# Run `seasonal_decompose` on the **original** (undifferenced) series and plot it.

# %%
#YOUR CODE HERE
decomposition = seasonal_decompose(df['thousands_of_passengers'], period=12)

decomposition.plot()
plt.gcf().set_size_inches(12, 8)
plt.show()

# %% [markdown]
# **What do you see in the seasonal component?** Is there a repeating pattern? What's the period (how many months before it repeats)?

# %% [markdown]
# ### B2. Search for a seasonal order with auto_arima
#
# Run `auto_arima` again, this time with `seasonal=True` and `m=12` (12 months per cycle).

# %%
#YOUR CODE HERE
auto_model_seasonal = auto_arima(df['thousands_of_passengers'],
                                 seasonal=True,     
                                 m=12,            
                                 trace=True,
                                 error_action='ignore',
                                 suppress_warnings=True)

auto_model_seasonal.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,1,1)[12]             : AIC=1020.048, Time=2.04 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=1031.508, Time=0.07 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=1020.393, Time=0.23 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=1021.003, Time=0.31 sec
#  ARIMA(2,1,2)(0,1,1)[12]             : AIC=1019.935, Time=1.10 sec
#  ARIMA(2,1,2)(0,1,0)[12]             : AIC=1019.290, Time=0.33 sec
#  ARIMA(2,1,2)(1,1,0)[12]             : AIC=1019.546, Time=0.96 sec
#  ARIMA(1,1,2)(0,1,0)[12]             : AIC=1024.160, Time=0.15 sec
#  ARIMA(2,1,1)(0,1,0)[12]             : AIC=1017.847, Time=0.32 sec
#  ARIMA(2,1,1)(1,1,0)[12]             : AIC=1017.914, Time=0.84 sec
#  ARIMA(2,1,1)(0,1,1)[12]             : AIC=1018.359, Time=0.86 sec
#  ARIMA(2,1,1)(1,1,1)[12]             : AIC=1018.248, Time=2.01 sec
#  ARIMA(1,1,1)(0,1,0)[12]             : AIC=1022.393, Time=0.18 sec
#  ARIMA(2,1,0)(0,1,0)[12]             : AIC=1022.393, Time=0.12 sec
#  ARIMA(3,1,1)(0,1,0)[12]             : AIC=1019.084, Time=0.42 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=1020.393, Time=0.07 sec
#  ARIMA(3,1,0)(0,1,0)[12]             : AIC=1023.666, Time=0.14 sec
#  ARIMA(3,1,2)(0,1,0)[12]             : AIC=1021.083, Time=1.14 sec
#  ARIMA(2,1,1)(0,1,0)[12] intercept   : AIC=inf, Time=1.00 sec
#
# Best model:  ARIMA(2,1,1)(0,1,0)[12]
# Total fit time: 12.374 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                                   y   No. Observations:                  144
# Model:             SARIMAX(2, 1, 1)x(0, 1, [], 12)   Log Likelihood                -504.923
# Date:                             Fri, 14 Aug 2026   AIC                           1017.847
# Time:                                     23:37:17   BIC                           1029.348
# Sample:                                 01-01-1949   HQIC                          1022.520
#                                       - 12-01-1960
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.5960      0.085      6.987      0.000       0.429       0.763
# ar.L2          0.2143      0.091      2.343      0.019       0.035       0.394
# ma.L1         -0.9819      0.038    -25.602      0.000      -1.057      -0.907
# sigma2       129.3128     14.556      8.884      0.000     100.783     157.843
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 7.68
# Prob(Q):                              0.98   Prob(JB):                         0.02
# Heteroskedasticity (H):               2.33   Skew:                            -0.01
# Prob(H) (two-sided):                  0.01   Kurtosis:                         4.19
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# **Write down the order and seasonal_order suggested:**
#
# - order (p,d,q) = 2,1,1
# - seasonal_order (P,D,Q,m) = 0,1,0,12

# %% [markdown]
# ### B3. Fit the SARIMA model
#
# Use `SARIMAX` with both `order` and `seasonal_order`, fit on `df_train`.

# %%
#YOUR CODE HERE
model_sarima = SARIMAX(df_train['thousands_of_passengers'],
                       order=(2, 1, 1),
                       seasonal_order=(0, 1, 0, 12))
result_sarima = model_sarima.fit(disp=False)

result_sarima.summary()
# Out:
# C:\Users\meqda\GA_DSB\ga_dsb_env\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\meqda\GA_DSB\ga_dsb_env\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:             thousands_of_passengers   No. Observations:                  132
# Model:             SARIMAX(2, 1, 1)x(0, 1, [], 12)   Log Likelihood                -447.483
# Date:                             Fri, 14 Aug 2026   AIC                            902.967
# Time:                                     23:40:04   BIC                            914.083
# Sample:                                 01-01-1949   HQIC                           907.481
#                                       - 12-01-1959
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.5253      0.929     -0.566      0.572      -2.345       1.295
# ar.L2          0.0110      0.275      0.040      0.968      -0.529       0.551
# ma.L1          0.3064      0.935      0.328      0.743      -1.527       2.140
# sigma2       108.0093     13.498      8.002      0.000      81.553     134.466
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 1.39
# Prob(Q):                              0.97   Prob(JB):                         0.50
# Heteroskedasticity (H):               1.47   Skew:                            -0.09
# Prob(H) (two-sided):                  0.23   Kurtosis:                         3.50
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ### B4. Predict on the test set, with confidence intervals
#
# This time, also pull the confidence interval so you can plot forecast uncertainty.

# %%
#YOUR CODE HERE
forecast_obj = result_sarima.get_forecast(steps=12)
pred_sarima = forecast_obj.predicted_mean.rename('SARIMA Predictions')
print(pred_sarima)
# Out:
# 1960-01-01    425.135148
# 1960-02-01    408.815436
# 1960-03-01    471.901435
# 1960-04-01    462.399948
# 1960-05-01    486.128077
# 1960-06-01    538.276346
# 1960-07-01    614.195485
# 1960-08-01    625.239584
# 1960-09-01    529.215534
# 1960-10-01    473.228650
# 1960-11-01    428.221497
# 1960-12-01    471.225398
# Freq: MS, Name: SARIMA Predictions, dtype: float64

# %% [markdown]
# ### B5. Evaluate

# %%
# Compute RMSE
error_sarima = rmse(df_test['thousands_of_passengers'], pred_sarima)

print(f'SARIMA(2,1,1)(0,1,0,12) RMSE: {error_sarima:.4f}')
# Out:
# SARIMA(2,1,1)(0,1,0,12) RMSE: 24.8741

# %% [markdown]
# ### B6. ARIMA vs. SARIMA
#
# Plot both sets of predictions against the actual test values side by side and print both RMSEs together.

# %%
#YOUR CODE HERE
# plot both models against the actual test values
fig, ax = plt.subplots(figsize=(12, 6))

df_test['thousands_of_passengers'].plot(ax=ax, label='Actual', linewidth=3)
pred_arima.plot(ax=ax, label=f'ARIMA(4,1,3)  RMSE={error_arima:.2f}')
pred_sarima.plot(ax=ax, label=f'SARIMA(2,1,1)(0,1,0,12)  RMSE={error_sarima:.2f}')

ax.legend()
plt.title('ARIMA vs SARIMA on the test set')
plt.ylabel('Passengers (thousands)')
plt.show()

print(f'ARIMA  RMSE: {error_arima:.4f}')
print(f'SARIMA RMSE: {error_sarima:.4f}')
# Out:
# ARIMA  RMSE: 87.6400
# SARIMA RMSE: 24.8741

# %% [markdown]
# <a id='forecast'></a>
# ## 2. Forecast the future
#
# Retrain your **winning model** on the *full* dataset and forecast 12 months into the future
#
# **Bonus**: *Plot the forecast with confidence intervals*.

# %%
#YOUR CODE HERE
model_full = SARIMAX(df['thousands_of_passengers'],
                     order=(2, 1, 1),
                     seasonal_order=(0, 1, 0, 12))
result_full = model_full.fit(disp=False)

future = result_full.get_forecast(steps=12)
forecast_mean = future.predicted_mean.rename('Forecast')

print("Forecast for 1961:")
print(forecast_mean.round(1))
# Out:
# C:\Users\meqda\GA_DSB\ga_dsb_env\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\meqda\GA_DSB\ga_dsb_env\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# Forecast for 1961:
# 1961-01-01    445.6
# 1961-02-01    420.4
# 1961-03-01    449.2
# 1961-04-01    491.8
# 1961-05-01    503.4
# 1961-06-01    566.9
# 1961-07-01    654.3
# 1961-08-01    638.6
# 1961-09-01    540.9
# 1961-10-01    494.1
# 1961-11-01    423.3
# 1961-12-01    465.5
# Freq: MS, Name: Forecast, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(12, 6))

df['thousands_of_passengers'].plot(ax=ax, label='Historical data')
forecast_mean.plot(ax=ax, label='12-month forecast')

ax.fill_between(forecast_ci.index,
                forecast_ci.iloc[:, 0],
                forecast_ci.iloc[:, 1],
                color='grey', alpha=0.3, label='95% confidence interval')

ax.legend()
plt.title('Airline passengers: 12-month forecast for 1961')
plt.ylabel('Passengers (thousands)')
plt.show()

# %% [markdown]
# ## Takeaways
# - Seasonality is easy to miss if you don't plot/decompose the data, hence, always look before you model.
# - SARIMA isn't automatically the right call; it's justified when the seasonal component is real and the added parameters actually reduce error on held-out data.
# - Always evaluate on a proper time-ordered train,test, and split.

# %% [markdown]
# ## Additional Resources
# - [statsmodels SARIMAX documentation](https://www.statsmodels.org/stable/generated/statsmodels.tsa.statespace.sarimax.SARIMAX.html)
# - [pmdarima auto_arima documentation](https://alkaline-ml.com/pmdarima/modules/generated/pmdarima.arima.auto_arima.html)
# - [Forecasting: Principles and Practice - Seasonal ARIMA](https://otexts.com/fpp2/seasonal-arima.html)
